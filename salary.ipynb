# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('salary_dataset.csv')

# %%
df.head()
# Out:
#    Unnamed: 0  YearsExperience   Salary
# 0           0              1.2  39344.0
# 1           1              1.4  46206.0
# 2           2              1.6  37732.0
# 3           3              2.1  43526.0
# 4           4              2.3  39892.0

# %%
df.tail()
# Out:
#     Unnamed: 0  YearsExperience    Salary
# 25          25              9.1  105583.0
# 26          26              9.6  116970.0
# 27          27              9.7  112636.0
# 28          28             10.4  122392.0
# 29          29             10.6  121873.0

# %%
df.describe()
# Out:
#        Unnamed: 0  YearsExperience         Salary
# count   30.000000        30.000000      30.000000
# mean    14.500000         5.413333   76004.000000
# std      8.803408         2.837888   27414.429785
# min      0.000000         1.200000   37732.000000
# 25%      7.250000         3.300000   56721.750000
# 50%     14.500000         4.800000   65238.000000
# 75%     21.750000         7.800000  100545.750000
# max     29.000000        10.600000  122392.000000

# %%
df.isnull().sum()
# Out:
# Unnamed: 0         0
# YearsExperience    0
# Salary             0
# dtype: int64

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'YearsExperience', 'Salary'], dtype='str')

# %%
df.shape
# Out:
# (30, 3)

# %%
df.isnull().sum()
# Out:
# Unnamed: 0         0
# YearsExperience    0
# Salary             0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.dtypes
# Out:
# Unnamed: 0           int64
# YearsExperience    float64
# Salary             float64
# dtype: object

# %%
plt.figure(figsize=(8,5))
sns.histplot(df['Salary'], bins=30, kde=True)
# Out:
# <Axes: xlabel='Salary', ylabel='Count'>

# %%
plt.figure(figsize=(8,5))
sns.histplot(df['YearsExperience'], bins=30, kde=True)
# Out:
# <Axes: xlabel='YearsExperience', ylabel='Count'>

# %%
sns.histplot(df['Salary'], kde=True)
# Out:
# <Axes: xlabel='Salary', ylabel='Count'>

# %%
df.head()
# Out:
#    Unnamed: 0  YearsExperience   Salary
# 0           0              1.2  39344.0
# 1           1              1.4  46206.0
# 2           2              1.6  37732.0
# 3           3              2.1  43526.0
# 4           4              2.3  39892.0

# %%
sns.histplot(df['YearsExperience'], kde=True)
# Out:
# <Axes: xlabel='YearsExperience', ylabel='Count'>

# %%
sns.boxplot(x=df['Salary'])
# Out:
# <Axes: xlabel='Salary'>

# %%
sns.boxplot(x=df['YearsExperience'])
# Out:
# <Axes: xlabel='YearsExperience'>

# %%
df = df.drop('Unnamed: 0', axis=1,inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 df = df.drop('Unnamed: 0', axis=1,inplace=True)
#
# File /workspaces/python_practise/.venv/lib/python3.12/site-packages/pandas/core/frame.py:6300, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    6296                 weight  250.0   150.0
#    6297         falcon  speed   320.0   250.0
#    6298                 weight  1.0     0.8
#    6299         """
# -> 6300         return super().drop(
#    6301             labels=labels,
#    6302             axis=axis,
#    6303             index=index,
#
# File /workspaces/python_practise/.venv/lib/python3.12/site-packages/pandas/core/generic.py:4644, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4640         obj = self
#    4641
#    4642         for axis, labels in axes.items():
#    4643             if labels is not None:
# -> 4644                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4645
#    4646         if inplace:
#    4647             self._update_inplace(obj)
#
# File /workspaces/python_practise/.venv/lib/python3.12/site-packages/pandas/core/generic.py:4686, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4682                 if not isinstance(axis, MultiIndex):
#    4683                     raise AssertionError("axis must be a MultiIndex")
#    4684                 new_axis = axis.drop(labels, level=level, errors=errors)
#    4685             else:
# -> 4686                 new_axis = axis.drop(labels, errors=errors)
#    4687             indexer = axis.get_indexer(new_axis)
#    4688
#    4689         # Case for non-unique axis
#
# File /workspaces/python_practise/.venv/lib/python3.12/site-packages/pandas/core/indexes/base.py:7268, in Index.drop(self, labels, errors)
#    7266 if mask.any():
#    7267     if errors != "ignore":
# -> 7268         raise KeyError(f"{labels[mask].tolist()} not found in axis")
#    7269     indexer = indexer[~mask]
#    7270 return self.delete(indexer)
#
# KeyError: "['Unnamed: 0'] not found in axis"

# %%
df
# Out:
#     YearsExperience    Salary
# 0               1.2   39344.0
# 1               1.4   46206.0
# 2               1.6   37732.0
# 3               2.1   43526.0
# 4               2.3   39892.0
# 5               3.0   56643.0
# 6               3.1   60151.0
# 7               3.3   54446.0
# 8               3.3   64446.0
# 9               3.8   57190.0
# 10              4.0   63219.0
# 11              4.1   55795.0
# 12              4.1   56958.0
# 13              4.2   57082.0
# 14              4.6   61112.0
# 15              5.0   67939.0
# 16              5.2   66030.0
# 17              5.4   83089.0
# 18              6.0   81364.0
# 19              6.1   93941.0
# 20              6.9   91739.0
# 21              7.2   98274.0
# 22              8.0  101303.0
# 23              8.3  113813.0
# 24              8.8  109432.0
# 25              9.1  105583.0
# 26              9.6  116970.0
# 27              9.7  112636.0
# 28             10.4  122392.0
# 29             10.6  121873.0
